# %% [markdown]
# ## <b>This is a notebook by Kevin Mugo Mwaniki</b>
#
# # <u>Chapter 4: SELECTING SUBSETS OF DATA</u>
# <p>The main difference between Pandas and the way Numpy handles data is in the indexing bit. Indexing can be done by labels and integer location of rows and columns</p>

# %% [markdown]
# ## <u>Selecting Series data</u>
# <p>The commonly used indexing operators are loc and iloc. <b>loc</b> is used to fetch label locators and <b>iloc</b> is used to fetch index locators</p>

# %%
import numpy as np
import pandas as pd

# %%
college = pd.read_csv('data/college.csv', index_col = 'INSTNM')

# %%
college.head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
# ...

# %%
#Selecting a single column as a Series:
city = college['CITY']

# %%
city.head()
# Out:
# INSTNM
# Alabama A & M University                   Normal
# University of Alabama at Birmingham    Birmingham
# Amridge University                     Montgomery
# University of Alabama in Huntsville    Huntsville
# Alabama State University               Montgomery
# Name: CITY, dtype: object

# %%
#Indexing starts from zero. To select the fourth row:
city.iloc[3]
# Out:
# 'Huntsville'

# %%
#Selection of several integer locations:
city.iloc[[10, 20, 30]]
# Out:
# INSTNM
# Birmingham Southern College                            Birmingham
# George C Wallace State Community College-Hanceville    Hanceville
# Judson College                                             Marion
# Name: CITY, dtype: object

# %%
#Selecting an equally spaced partitions of data:
#It uses the start, stop and steps syntax
city.iloc[4:50:10]
# Out:
# INSTNM
# Alabama State University              Montgomery
# Enterprise State Community College    Enterprise
# Heritage Christian University           Florence
# Marion Military Institute                 Marion
# Reid State Technical College           Evergreen
# Name: CITY, dtype: object

# %%
#Selecting labeled data by index:
city.loc['Heritage Christian University']
# Out:
# 'Florence'

# %%
#Selecting 4 random rows using the lists format:
np.random.seed(1)
labels = list(np.random.choice(city.index, 4))
labels
# Out:
# ['Northwest HVAC/R Training Center',
#  'California State University-Dominguez Hills',
#  'Lower Columbia College',
#  'Southwest Acupuncture College-Boulder']

# %%
city.loc[labels]
# Out:
# INSTNM
# Northwest HVAC/R Training Center                Spokane
# California State University-Dominguez Hills      Carson
# Lower Columbia College                         Longview
# Southwest Acupuncture College-Boulder           Boulder
# Name: CITY, dtype: object

# %%
#Equally spaced data using equal step sizes:
city.loc['Alabama State University': 'Reid State Technical College':10]
# Out:
# INSTNM
# Alabama State University              Montgomery
# Enterprise State Community College    Enterprise
# Heritage Christian University           Florence
# Marion Military Institute                 Marion
# Reid State Technical College           Evergreen
# Name: CITY, dtype: object

# %%
#To get an output that also includes the index that the filter had as its output:
city.iloc[[3]]
# Out:
# INSTNM
# University of Alabama in Huntsville    Huntsville
# Name: CITY, dtype: object

# %%
#This was the initial output that was being obtained:
city.iloc[3]
# Out:
# 'Huntsville'

# %%
#If the start is after the stop in the steps format, an empty Series is returned without an exception raised:
city.loc['Reid State Technical College': 'Alabama State University' : 10]
# Out:
# Series([], Name: CITY, dtype: object)

# %%
city.loc['Alabama State University' : 'Reid State Technical College' : 10]
# Out:
# INSTNM
# Alabama State University              Montgomery
# Enterprise State Community College    Enterprise
# Heritage Christian University           Florence
# Marion Military Institute                 Marion
# Reid State Technical College           Evergreen
# Name: CITY, dtype: object

# %% [markdown]
# ## <u>Selecting DataFrame rows</u>
# <p>The loc and iloc indexers can still be used to select rows and columns simultaneously:</p>

# %%
college.head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
# ...

# %%
#Selecting an entire row:
college.iloc[60]
# Out:
# CITY                  Anchorage
# STABBR                       AK
# HBCU                          0
# MENONLY                       0
# WOMENONLY                     0
# RELAFFIL                      0
# SATVRMID                    NaN
# SATMTMID                    NaN
# DISTANCEONLY                  0
# UGDS                      12865
# UGDS_WHITE               0.5747
# UGDS_BLACK               0.0358
# UGDS_HISP                0.0761
# UGDS_ASIAN               0.0778
# UGDS_AIAN                0.0653
# UGDS_NHPI                0.0086
# UGDS_2MOR                 0.098
# UGDS_NRA                 0.0181
# UGDS_UNKN                0.0457
# PPTUG_EF                 0.4539
# CURROPER                      1
# PCTPELL                  0.2385
# PCTFLOAN                 0.2647
# UG25ABV                  0.4386
# MD_EARN_WNE_P10           42500
# GRAD_DEBT_MDN_SUPP      19449.5
# Name: University of Alaska Anchorage, dtype: object

# %%
#The same row can also be accessed using the index label:
college.loc['University of Alaska Anchorage']
# Out:
# CITY                  Anchorage
# STABBR                       AK
# HBCU                          0
# MENONLY                       0
# WOMENONLY                     0
# RELAFFIL                      0
# SATVRMID                    NaN
# SATMTMID                    NaN
# DISTANCEONLY                  0
# UGDS                      12865
# UGDS_WHITE               0.5747
# UGDS_BLACK               0.0358
# UGDS_HISP                0.0761
# UGDS_ASIAN               0.0778
# UGDS_AIAN                0.0653
# UGDS_NHPI                0.0086
# UGDS_2MOR                 0.098
# UGDS_NRA                 0.0181
# UGDS_UNKN                0.0457
# PPTUG_EF                 0.4539
# CURROPER                      1
# PCTPELL                  0.2385
# PCTFLOAN                 0.2647
# UG25ABV                  0.4386
# MD_EARN_WNE_P10           42500
# GRAD_DEBT_MDN_SUPP      19449.5
# Name: University of Alaska Anchorage, dtype: object

# %%
#To select several disjointed rows:
college.iloc[[60, 99, 3]]
# Out:
#                                             CITY STABBR  HBCU  MENONLY  \
# INSTNM
# University of Alaska Anchorage         Anchorage     AK   0.0      0.0
# International Academy of Hair Design       Tempe     AZ   0.0      0.0
# University of Alabama in Huntsville   Huntsville     AL   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# University of Alaska Anchorage              0.0         0       NaN       NaN
# International Academy of Hair Design        0.0         0       NaN       NaN
# University of Alabama in Huntsville         0.0         0     595.0     590.0
#
#                                       DISTANCEONLY     UGDS  ...  UGDS_2MOR  \
# INSTNM                                                       ...
# University of Alaska Anchorage                 0.0  12865.0  ...     0.0980
# International Academy of Hair Design           0.0    188.0  ...     0.0160
# ...

# %%
#An alternative for the above code is:
labels = ['University of Alaska Anchorage',
'International Academy of Hair Design',
'University of Alabama in Huntsville']

# %%
college.loc[labels]
# Out:
#                                             CITY STABBR  HBCU  MENONLY  \
# INSTNM
# University of Alaska Anchorage         Anchorage     AK   0.0      0.0
# International Academy of Hair Design       Tempe     AZ   0.0      0.0
# University of Alabama in Huntsville   Huntsville     AL   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# University of Alaska Anchorage              0.0         0       NaN       NaN
# International Academy of Hair Design        0.0         0       NaN       NaN
# University of Alabama in Huntsville         0.0         0     595.0     590.0
#
#                                       DISTANCEONLY     UGDS  ...  UGDS_2MOR  \
# INSTNM                                                       ...
# University of Alaska Anchorage                 0.0  12865.0  ...     0.0980
# International Academy of Hair Design           0.0    188.0  ...     0.0160
# ...

# %%
#An alternative to the code above is as follows:
college.iloc[[60, 99, 3]].index.tolist()
# Out:
# ['University of Alaska Anchorage',
#  'International Academy of Hair Design',
#  'University of Alabama in Huntsville']

# %%
#Slicing of data can be done as follows:
college.iloc[99:102]
# Out:
#                                          CITY STABBR  HBCU  MENONLY  \
# INSTNM
# International Academy of Hair Design    Tempe     AZ   0.0      0.0
# GateWay Community College             Phoenix     AZ   0.0      0.0
# Mesa Community College                   Mesa     AZ   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# International Academy of Hair Design        0.0         0       NaN       NaN
# GateWay Community College                   0.0         0       NaN       NaN
# Mesa Community College                      0.0         0       NaN       NaN
#
#                                       DISTANCEONLY     UGDS  ...  UGDS_2MOR  \
# INSTNM                                                       ...
# International Academy of Hair Design           0.0    188.0  ...     0.0160
# GateWay Community College                      0.0   5211.0  ...     0.0127
# ...

# %%
start = 'International Academy of Hair Design'
stop = 'Mesa Community College'
college.loc[start:stop]
# Out:
#                                          CITY STABBR  HBCU  MENONLY  \
# INSTNM
# International Academy of Hair Design    Tempe     AZ   0.0      0.0
# GateWay Community College             Phoenix     AZ   0.0      0.0
# Mesa Community College                   Mesa     AZ   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# International Academy of Hair Design        0.0         0       NaN       NaN
# GateWay Community College                   0.0         0       NaN       NaN
# Mesa Community College                      0.0         0       NaN       NaN
#
#                                       DISTANCEONLY     UGDS  ...  UGDS_2MOR  \
# INSTNM                                                       ...
# International Academy of Hair Design           0.0    188.0  ...     0.0160
# GateWay Community College                      0.0   5211.0  ...     0.0127
# ...

# %% [markdown]
# ## <u>Selecting DataFrame rows and columns simultaneously</u>
# <p>It uses the <b>df.iloc[rows, columns]</b> or the <b>df.loc[rows, columns]</b> syntax where the row and columns values may be scalars, lists, slice objects or boolean sequences<p>

# %%
#Selection of the first three rows and the first four columns using the slice notation:
college.iloc[:3, :4]
# Out:
#                                            CITY STABBR  HBCU  MENONLY
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0

# %%
#List values format to select two different columns:
college.iloc[:, [4, 6]].head()
# Out:
#                                      WOMENONLY  SATVRMID
# INSTNM
# Alabama A & M University                   0.0     424.0
# University of Alabama at Birmingham        0.0     570.0
# Amridge University                         0.0       NaN
# University of Alabama in Huntsville        0.0     595.0
# Alabama State University                   0.0     425.0

# %%
college.loc[:, ['WOMENONLY', 'SATVRMID']].head()
# Out:
#                                      WOMENONLY  SATVRMID
# INSTNM
# Alabama A & M University                   0.0     424.0
# University of Alabama at Birmingham        0.0     570.0
# Amridge University                         0.0       NaN
# University of Alabama in Huntsville        0.0     595.0
# Alabama State University                   0.0     425.0

# %%
#Selecting disjointed rows and columns:
college.iloc[[100, 200], [7, 15]]
# Out:
#                                        SATMTMID  UGDS_NHPI
# INSTNM
# GateWay Community College                   NaN     0.0029
# American Baptist Seminary of the West       NaN        NaN

# %%
rows = ['GateWay Community College', 'American Baptist Seminary of the West']

# %%
columns = ['SATMTMID', 'UGDS_NHPI']

# %%
college.loc[rows, columns]
# Out:
#                                        SATMTMID  UGDS_NHPI
# INSTNM
# GateWay Community College                   NaN     0.0029
# American Baptist Seminary of the West       NaN        NaN

# %%
college.columns
# Out:
# Index(['CITY', 'STABBR', 'HBCU', 'MENONLY', 'WOMENONLY', 'RELAFFIL',
#        'SATVRMID', 'SATMTMID', 'DISTANCEONLY', 'UGDS', 'UGDS_WHITE',
#        'UGDS_BLACK', 'UGDS_HISP', 'UGDS_ASIAN', 'UGDS_AIAN', 'UGDS_NHPI',
#        'UGDS_2MOR', 'UGDS_NRA', 'UGDS_UNKN', 'PPTUG_EF', 'CURROPER', 'PCTPELL',
#        'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10', 'GRAD_DEBT_MDN_SUPP'],
#       dtype='object')

# %%
#Selecting a single scalar values:
college.iloc[5, -4]
# Out:
# 0.401

# %%
#Alternatively:
college.loc['The University of Alabama', 'PCTFLOAN']
# Out:
# 0.401

# %%
college.iloc[90:80:-2, 5]
start = 'Empire Beauty School-Flagstaff'
stop = 'Arizona State University-Tempe'
college.loc[start:stop:-2, 'RELAFFIL']
# Out:
# INSTNM
# Empire Beauty School-Flagstaff     0
# Charles of Italy Beauty College    0
# Central Arizona College            0
# University of Arizona              0
# Arizona State University-Tempe     0
# Name: RELAFFIL, dtype: int64

# %%
#This code syntax is similar to the one below it:
college.iloc[:10]
# Out:
#                                                CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                     Normal     AL   1.0      0.0
# University of Alabama at Birmingham      Birmingham     AL   0.0      0.0
# Amridge University                       Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville      Huntsville     AL   0.0      0.0
# Alabama State University                 Montgomery     AL   1.0      0.0
# The University of Alabama                Tuscaloosa     AL   0.0      0.0
# Central Alabama Community College    Alexander City     AL   0.0      0.0
# Athens State University                      Athens     AL   0.0      0.0
# Auburn University at Montgomery          Montgomery     AL   0.0      0.0
# Auburn University                            Auburn     AL   0.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# ...

# %%
college.iloc[:10, :]
# Out:
#                                                CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                     Normal     AL   1.0      0.0
# University of Alabama at Birmingham      Birmingham     AL   0.0      0.0
# Amridge University                       Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville      Huntsville     AL   0.0      0.0
# Alabama State University                 Montgomery     AL   1.0      0.0
# The University of Alabama                Tuscaloosa     AL   0.0      0.0
# Central Alabama Community College    Alexander City     AL   0.0      0.0
# Athens State University                      Athens     AL   0.0      0.0
# Auburn University at Montgomery          Montgomery     AL   0.0      0.0
# Auburn University                            Auburn     AL   0.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# ...

# %% [markdown]
# ## <u>Selecting data with both integers and labels</u>
# <p>In previous Pandas versions, the .ix indexer had the ability to select both integer and label location but it was very
# ambiguous and was a source of confusion for many Pandas users. The indexer is currently depreciated and should be avoided. It
# was previously possible to write selection code such as <b><i>college.ix[:5,'UGDS_WHITE':'UGDS_UNKN'].</i></b> This is now impossible when loc or iloc are used. We will now get into finding the integer location of the columns then use iloc to complete the selection.</p>

# %%
college = pd.read_csv('data/college.csv', index_col = 'INSTNM')

# %%
college.head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
# ...

# %%
#Use the get_loc index method to get the index location of the desired columns:
col_start = college.columns.get_loc('UGDS_WHITE')
col_end = college.columns.get_loc('UGDS_UNKN') + 1
col_start, col_end
# Out:
# (10, 19)

# %%
#Use col_start and col_end to select the first five rows of columns by integer location using iloc:
college.iloc[:5, col_start : col_end]
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                 0.0333      0.9353     0.0055
# University of Alabama at Birmingham      0.5922      0.2600     0.0283
# Amridge University                       0.2990      0.4192     0.0069
# University of Alabama in Huntsville      0.6988      0.1255     0.0382
# Alabama State University                 0.0158      0.9208     0.0121
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                 0.0019     0.0024     0.0019
# University of Alabama at Birmingham      0.0518     0.0022     0.0007
# Amridge University                       0.0034     0.0000     0.0000
# University of Alabama in Huntsville      0.0376     0.0143     0.0002
# Alabama State University                 0.0019     0.0010     0.0006
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
#Selecting an entire row at that position:
college.iloc[2]
# Out:
# CITY                  Montgomery
# STABBR                        AL
# HBCU                           0
# MENONLY                        0
# WOMENONLY                      0
# RELAFFIL                       1
# SATVRMID                     NaN
# SATMTMID                     NaN
# DISTANCEONLY                   1
# UGDS                         291
# UGDS_WHITE                 0.299
# UGDS_BLACK                0.4192
# UGDS_HISP                 0.0069
# UGDS_ASIAN                0.0034
# UGDS_AIAN                      0
# UGDS_NHPI                      0
# UGDS_2MOR                      0
# UGDS_NRA                       0
# UGDS_UNKN                 0.2715
# PPTUG_EF                  0.4536
# CURROPER                       1
# PCTPELL                   0.6801
# PCTFLOAN                  0.7795
# UG25ABV                    0.854
# MD_EARN_WNE_P10            40100
# GRAD_DEBT_MDN_SUPP         23370
# Name: Amridge University, dtype: object

# %%
#Alternatively:
college.loc['University of Alaska Anchorage']
# Out:
# CITY                  Anchorage
# STABBR                       AK
# HBCU                          0
# MENONLY                       0
# WOMENONLY                     0
# RELAFFIL                      0
# SATVRMID                    NaN
# SATMTMID                    NaN
# DISTANCEONLY                  0
# UGDS                      12865
# UGDS_WHITE               0.5747
# UGDS_BLACK               0.0358
# UGDS_HISP                0.0761
# UGDS_ASIAN               0.0778
# UGDS_AIAN                0.0653
# UGDS_NHPI                0.0086
# UGDS_2MOR                 0.098
# UGDS_NRA                 0.0181
# UGDS_UNKN                0.0457
# PPTUG_EF                 0.4539
# CURROPER                      1
# PCTPELL                  0.2385
# PCTFLOAN                 0.2647
# UG25ABV                  0.4386
# MD_EARN_WNE_P10           42500
# GRAD_DEBT_MDN_SUPP      19449.5
# Name: University of Alaska Anchorage, dtype: object

# %%
#Selection of a disjointed set of rows:
college.iloc[[60, 99, 3]]
# Out:
#                                             CITY STABBR  HBCU  MENONLY  \
# INSTNM
# University of Alaska Anchorage         Anchorage     AK   0.0      0.0
# International Academy of Hair Design       Tempe     AZ   0.0      0.0
# University of Alabama in Huntsville   Huntsville     AL   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# University of Alaska Anchorage              0.0         0       NaN       NaN
# International Academy of Hair Design        0.0         0       NaN       NaN
# University of Alabama in Huntsville         0.0         0     595.0     590.0
#
#                                       DISTANCEONLY     UGDS  ...  UGDS_2MOR  \
# INSTNM                                                       ...
# University of Alaska Anchorage                 0.0  12865.0  ...     0.0980
# International Academy of Hair Design           0.0    188.0  ...     0.0160
# ...

# %%
#Alternatively:
labels = ['University of Alaska Anchorage',
          'International Academy of Hair Design',
          'University of Alabama in Huntsville']

# %%
#You can also get the list of indexes without copying and pasting:
college.iloc[[60, 99, 3]].index.tolist()
# Out:
# ['University of Alaska Anchorage',
#  'International Academy of Hair Design',
#  'University of Alabama in Huntsville']

# %%
college.loc[labels]
# Out:
#                                             CITY STABBR  HBCU  MENONLY  \
# INSTNM
# University of Alaska Anchorage         Anchorage     AK   0.0      0.0
# International Academy of Hair Design       Tempe     AZ   0.0      0.0
# University of Alabama in Huntsville   Huntsville     AL   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# University of Alaska Anchorage              0.0         0       NaN       NaN
# International Academy of Hair Design        0.0         0       NaN       NaN
# University of Alabama in Huntsville         0.0         0     595.0     590.0
#
#                                       DISTANCEONLY     UGDS  ...  UGDS_2MOR  \
# INSTNM                                                       ...
# University of Alaska Anchorage                 0.0  12865.0  ...     0.0980
# International Academy of Hair Design           0.0    188.0  ...     0.0160
# ...

# %%
#Slicing can also be done as follows:
college.iloc[99:102]
# Out:
#                                          CITY STABBR  HBCU  MENONLY  \
# INSTNM
# International Academy of Hair Design    Tempe     AZ   0.0      0.0
# GateWay Community College             Phoenix     AZ   0.0      0.0
# Mesa Community College                   Mesa     AZ   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# International Academy of Hair Design        0.0         0       NaN       NaN
# GateWay Community College                   0.0         0       NaN       NaN
# Mesa Community College                      0.0         0       NaN       NaN
#
#                                       DISTANCEONLY     UGDS  ...  UGDS_2MOR  \
# INSTNM                                                       ...
# International Academy of Hair Design           0.0    188.0  ...     0.0160
# GateWay Community College                      0.0   5211.0  ...     0.0127
# ...

# %%
college.iloc[102]
# Out:
# CITY                   Tucson
# STABBR                     AZ
# HBCU                        0
# MENONLY                     0
# WOMENONLY                   0
# RELAFFIL                    0
# SATVRMID                  NaN
# SATMTMID                  NaN
# DISTANCEONLY                0
# UGDS                      400
# UGDS_WHITE             0.4375
# UGDS_BLACK             0.0625
# UGDS_HISP              0.3375
# UGDS_ASIAN             0.0275
# UGDS_AIAN              0.0525
# UGDS_NHPI               0.005
# UGDS_2MOR               0.035
# UGDS_NRA                    0
# UGDS_UNKN              0.0425
# PPTUG_EF                 0.24
# CURROPER                    0
# PCTPELL                0.8191
# PCTFLOAN               0.7311
# UG25ABV                0.7457
# MD_EARN_WNE_P10         38800
# GRAD_DEBT_MDN_SUPP    25827.5
# Name: ITT Technical Institute-Tucson, dtype: object

# %%
#Slice notation works with the .loc indexer and it is inclusive of the last label:
start = 'International Academy of Hair Design'
stop = 'Mesa Community College'
college.loc[start:stop]
# Out:
#                                          CITY STABBR  HBCU  MENONLY  \
# INSTNM
# International Academy of Hair Design    Tempe     AZ   0.0      0.0
# GateWay Community College             Phoenix     AZ   0.0      0.0
# Mesa Community College                   Mesa     AZ   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# International Academy of Hair Design        0.0         0       NaN       NaN
# GateWay Community College                   0.0         0       NaN       NaN
# Mesa Community College                      0.0         0       NaN       NaN
#
#                                       DISTANCEONLY     UGDS  ...  UGDS_2MOR  \
# INSTNM                                                       ...
# International Academy of Hair Design           0.0    188.0  ...     0.0160
# GateWay Community College                      0.0   5211.0  ...     0.0127
# ...

# %%
#A replacement of the get_index method is this one:
row_start = college.index[10]
row_end = college.index[15]
college.loc[row_start : row_end, 'UGDS_WHITE':'UGDS_UNKN']
# Out:
#                                           UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Birmingham Southern College                   0.7983      0.1102     0.0195
# Chattahoochee Valley Community College        0.4661      0.4372     0.0492
# Concordia College Alabama                     0.0280      0.8758     0.0373
# South University-Montgomery                   0.3046      0.6054     0.0153
# Enterprise State Community College            0.6408      0.2435     0.0509
# James H Faulkner State Community College      0.6979      0.2259     0.0320
#
#                                           UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Birmingham Southern College                   0.0517     0.0102     0.0000
# Chattahoochee Valley Community College        0.0127     0.0023     0.0035
# Concordia College Alabama                     0.0093     0.0000     0.0000
# South University-Montgomery                   0.0153     0.0153     0.0096
# ...

# %%
#Chaining indexers is a bad idea but it can work:
college.iloc[10:16].loc[:, 'UGDS_WHITE':'UGDS_UNKN']
# Out:
#                                           UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Birmingham Southern College                   0.7983      0.1102     0.0195
# Chattahoochee Valley Community College        0.4661      0.4372     0.0492
# Concordia College Alabama                     0.0280      0.8758     0.0373
# South University-Montgomery                   0.3046      0.6054     0.0153
# Enterprise State Community College            0.6408      0.2435     0.0509
# James H Faulkner State Community College      0.6979      0.2259     0.0320
#
#                                           UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Birmingham Southern College                   0.0517     0.0102     0.0000
# Chattahoochee Valley Community College        0.0127     0.0023     0.0035
# Concordia College Alabama                     0.0093     0.0000     0.0000
# South University-Montgomery                   0.0153     0.0153     0.0096
# ...

# %% [markdown]
# ## <u>Speeding up scalar selection</u>
# <p>There are indexers <b>iat</b> and <b>at</b> which achieve the same thing at faster speeds. They only accept scalar values. They save several microseconds per loop if they may be used in a program</p>

# %%
cn = 'Texas A & M University-College Station'

# %%
college.loc[cn, 'UGDS_WHITE']
# Out:
# 0.6609999999999999

# %%
#The %timeit magic command can be used to compare the difference in speed:
# %timeit college.loc[cn, 'UGDS_WHITE']
# Out:
# 48.7 µs ± 817 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit college.at[cn, 'UGDS_WHITE']
# Out:
# 31.7 µs ± 902 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
row_num = college.index.get_loc(cn)
row_num
# Out:
# 3765

# %%
col_num = college.columns.get_loc('UGDS_WHITE')
col_num
# Out:
# 10

# %%
row_num, col_num
# Out:
# (3765, 10)

# %%
# %timeit college.iloc[row_num, col_num]
# Out:
# 52.5 µs ± 1.2 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit college.iat[row_num, col_num]
# Out:
# 38.3 µs ± 5.99 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
#.iat and .at work with Series as well. Pass them a scalar value and they will retur a scalar:
state = college['STABBR']

# %%
state.iat[1000]
# Out:
# 'IL'

# %%
state.at['Stanford University']
# Out:
# 'CA'

# %% [markdown]
# ## <u>Slicing rows lazily</u>
# <p>Rows can be sliced lazily without the use of loc or iloc. It does not work for columns, but just for DataFrame rows and Series. It cannot also be used to select rows and columns simultaneously</p>

# %%
college[10 : 20 : 2]
# Out:
#                                              CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Birmingham Southern College            Birmingham     AL   0.0      0.0
# Concordia College Alabama                   Selma     AL   1.0      0.0
# Enterprise State Community College     Enterprise     AL   0.0      0.0
# Faulkner University                    Montgomery     AL   0.0      0.0
# New Beginning College of Cosmetology  Albertville     AL   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Birmingham Southern College                 0.0         1     560.0     560.0
# Concordia College Alabama                   0.0         1     420.0     400.0
# Enterprise State Community College          0.0         0       NaN       NaN
# Faulkner University                         0.0         1       NaN       NaN
# New Beginning College of Cosmetology        0.0         0       NaN       NaN
#
# ...

# %%
#The same slicing exists with Series:
city = college['CITY']

# %%
city[10 : 20 : 2]
# Out:
# INSTNM
# Birmingham Southern College              Birmingham
# Concordia College Alabama                     Selma
# Enterprise State Community College       Enterprise
# Faulkner University                      Montgomery
# New Beginning College of Cosmetology    Albertville
# Name: CITY, dtype: object

# %%
#Series and DataFrames can slice by label with just the indexing operator:
start = 'Mesa Community College'
stop = 'Spokane Community College'
college[start:stop:1500]
# Out:
#                                                 CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Mesa Community College                          Mesa     AZ   0.0      0.0
# Hair Academy Inc-New Carrollton       New Carrollton     MD   0.0      0.0
# National College of Natural Medicine        Portland     OR   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Mesa Community College                      0.0         0       NaN       NaN
# Hair Academy Inc-New Carrollton             0.0         0       NaN       NaN
# National College of Natural Medicine        0.0         0       NaN       NaN
#
#                                       DISTANCEONLY     UGDS  ...  UGDS_2MOR  \
# INSTNM                                                       ...
# Mesa Community College                         0.0  19055.0  ...     0.0205
# Hair Academy Inc-New Carrollton                0.0    504.0  ...     0.0000
# ...

# %%
college.index.get_loc('Mesa Community College')
# Out:
# 101

# %%
college.index.get_loc('Spokane Community College')
# Out:
# 4001

# %%
#Here is the same slice label with a Series:
city[start:stop:1500]
# Out:
# INSTNM
# Mesa Community College                            Mesa
# Hair Academy Inc-New Carrollton         New Carrollton
# National College of Natural Medicine          Portland
# Name: CITY, dtype: object

# %% [markdown]
# ## <u>Slicing lexicographically</u>
# <p>The loc indexer can also be used to select data based on the order of the values in the index. It works with the slice notation only if the index is sorted:</p>

# %%
college = college.sort_index()

# %%
college.head()
# Out:
#                                                            CITY STABBR  HBCU  \
# INSTNM
# A & W Healthcare Educators                          New Orleans     LA   0.0
# A T Still University of Health Sciences              Kirksville     MO   0.0
# ABC Beauty Academy                                      Garland     TX   0.0
# ABC Beauty College Inc                              Arkadelphia     AR   0.0
# AI Miami International University of Art and De...        Miami     FL   0.0
#
#                                                     MENONLY  WOMENONLY  \
# INSTNM
# A & W Healthcare Educators                              0.0        0.0
# A T Still University of Health Sciences                 0.0        0.0
# ABC Beauty Academy                                      0.0        0.0
# ABC Beauty College Inc                                  0.0        0.0
# AI Miami International University of Art and De...      0.0        0.0
#
# ...

# %%
#This method is case-sensitive and is inclusive of the last index
#Python sorts capital letters before small letters and integers before capital letters
college.loc['Sp' : 'Su']
# Out:
#                                                   CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Spa Tech Institute-Ipswich                     Ipswich     MA   0.0      0.0
# Spa Tech Institute-Plymouth                   Plymouth     MA   0.0      0.0
# Spa Tech Institute-Westboro                   Westboro     MA   0.0      0.0
# Spa Tech Institute-Westbrook                 Westbrook     ME   0.0      0.0
# Spalding University                         Louisville     KY   0.0      0.0
# ...                                                ...    ...   ...      ...
# Studio Academy of Beauty                      Chandler     AZ   0.0      0.0
# Studio Jewelers                               New York     NY   0.0      0.0
# Stylemaster College of Hair Design            Longview     WA   0.0      0.0
# Styles and Profiles Beauty College              Selmer     TN   0.0      0.0
# Styletrends Barber and Hairstyling Academy   Rock Hill     SC   0.0      0.0
#
# ...

# %%
#It also works when the index is sorted in the opposite direction:
college = college.sort_index(ascending = False)

# %%
#Determining the direction which the index is sorted:
college.index.is_monotonic_decreasing
# Out:
# True

# %%
college.index.is_monotonic_increasing
# Out:
# False

# %%
college.loc['E' : 'B']
# Out:
#                                                   CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Dyersburg State Community College            Dyersburg     TN   0.0      0.0
# Dutchess Community College                Poughkeepsie     NY   0.0      0.0
# Dutchess BOCES-Practical Nursing Program  Poughkeepsie     NY   0.0      0.0
# Durham Technical Community College              Durham     NC   0.0      0.0
# Durham Beauty Academy                           Durham     NC   0.0      0.0
# ...                                                ...    ...   ...      ...
# Bacone College                                Muskogee     OK   0.0      0.0
# Babson College                               Wellesley     MA   0.0      0.0
# BJ's Beauty & Barber College                    Auburn     WA   0.0      0.0
# BIR Training Center                            Chicago     IL   0.0      0.0
# B M Spurr School of Practical Nursing        Glen Dale     WV   0.0      0.0
#
# ...

# %%
college.loc['B' : 'E']
# Out:
# Empty DataFrame
# Columns: [CITY, STABBR, HBCU, MENONLY, WOMENONLY, RELAFFIL, SATVRMID, SATMTMID, DISTANCEONLY, UGDS, UGDS_WHITE, UGDS_BLACK, UGDS_HISP, UGDS_ASIAN, UGDS_AIAN, UGDS_NHPI, UGDS_2MOR, UGDS_NRA, UGDS_UNKN, PPTUG_EF, CURROPER, PCTPELL, PCTFLOAN, UG25ABV, MD_EARN_WNE_P10, GRAD_DEBT_MDN_SUPP]
# Index: []
#
# [0 rows x 26 columns]
